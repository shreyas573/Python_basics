# %% [markdown]
# ## Tuples

# %%
t=(1,2,3,4,'kumar')
t
# Out:
# (1, 2, 3, 4, 'kumar')

# %%
t[2]
# Out:
# 3

# %%
#nested tuple
nested_tuple=(1,2,3,4,5,(7,8,9))
nested_tuple
# Out:
# (1, 2, 3, 4, 5, (7, 8, 9))

# %%
nested_tuple[3]
# Out:
# 4

# %%
nested_tuple[5]
# Out:
# (7, 8, 9)

# %%
nested_tuple[5][2]
# Out:
# 9

# %%
type(nested_tuple)
# Out:
# tuple

# %%
single_tuple=1,
single_tuple
# Out:
# (1,)

# %%
type(single_tuple)
# Out:
# tuple

# %% [markdown]
# ### indexing in tuple

# %% [markdown]
# ##### str=('mumbai',10,'python',100,'delhi')
# str

# %%
str[0:6]
# Out:
# ('mumbai', 10, 'python', 100, 'delhi')

# %%
str[1:4]
# Out:
# (10, 'python', 100)

# %%
str[3:]
# Out:
# (100, 'delhi')

# %%
str[-1:]
# Out:
# ('delhi',)

# %%
str[-4:]
# Out:
# (10, 'python', 100, 'delhi')

# %% [markdown]
# ### concatination

# %%
tuple_a=('welcome','to')
tuple_b=('jupyter','notebook')
concat_tuple=tuple_a+tuple_b
concat_tuple
# Out:
# ('welcome', 'to', 'jupyter', 'notebook')

# %% [markdown]
# ### min max sum functions

# %%
tuple_min=(1,2,3,4,5,6)
min(tuple_min)
# Out:
# 1

# %%
tuple_max=(1,2,3,4,5,6)
max(tuple_max)
# Out:
# 6

# %%
tuple_sum=(1,2,3,4,5)
sum(tuple_sum)
# Out:
# 15

# %%
S_tuple=(5,4,3,2,1)
sorted_tuple=sorted(S_tuple)
sorted_tuple
# Out:
# [1, 2, 3, 4, 5]

# %%
type(sorted_tuple)
# Out:
# list

# %%
new_tuple=tuple(sorted_tuple)
new_tuple
type(new_tuple)
# Out:
# tuple
