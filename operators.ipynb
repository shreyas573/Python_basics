# %%
#operators in python 
a=10
b=2

# %%
addition=a+b
addition
# Out:
# 12

# %%
subtraction=a-b
subtraction
# Out:
# 8

# %%
division=a*b
division
# Out:
# 20

# %%
multiplication=a/b
multiplication
# Out:
# 5.0

# %%
floor_division=a//b
floor_division
# Out:
# 5

# %%
modulo=a%b
modulo
# Out:
# 0

# %%
exponentiation=a**b
exponentiation
# Out:
# 100
