# %%
lists=[1,'shreyas',20000,22]
lists
# Out:
# [1, 'shreyas', 20000, 22]

# %%
len(lists)
# Out:
# 4

# %%
type(lists)
# Out:
# list

# %%
#nested list
nested_list=[1,'shreyas',20000,22,['shimoga','karnataka']]
nested_list
# Out:
# [1, 'shreyas', 20000, 22, ['shimoga', 'karnataka']]

# %%
nested_list[2]
# Out:
# 20000

# %%
nested_list[4][1]
# Out:
# 'karnataka'

# %%
#lists concatination
list1=[1,2,3,4]
list2=[4,5,6,8]
new_list=list1+list2
new_list
# Out:
# [1, 2, 3, 4, 4, 5, 6, 8]

# %%
len(new_list)
# Out:
# 8

# %% [markdown]
# ## mutability

# %%
m_list=['machine learning','NLP','Deep learning']
m_list
# Out:
# ['machine learning', 'NLP', 'Deep learning']

# %%
m_list[2]='data science'
m_list
# Out:
# ['machine learning', 'NLP', 'data science']

# %%
#extends the list
list1=[1,2,3,4]
list1.extend([5,6])
list1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
len(list1)
# Out:
# 6

# %%
#inserting elements
list1.append([2,3])
list1
# Out:
# [1, 2, 3, 4, 5, 6, [2, 3]]

# %%
#deleting element from the list

del list1[2]
list1
# Out:
# [1, 2, 4, 5, 6, [2, 3]]

# %%
#pop()->it removes last index element by default
list1.pop()
list1
# Out:
# [1, 2, 4, 5, 6]

# %%
#remove()->removes the element
list1.remove(6)
list1
# Out:
# [1, 2, 4, 5]

# %%
list_a=['mango','apple','grapes']
list_a.sort()
list_a
# Out:
# ['apple', 'grapes', 'mango']

# %%
list_b=['human','eye','computer','vision']
list_sort=sorted(list_b)
list_sort
# Out:
# ['computer', 'eye', 'human', 'vision']

# %%
#shallow copy
copy_list=list_a
copy_list
# Out:
# ['apple', 'grapes', 'mango']
