# %% [markdown]
# ## Dictionary

# %%
dictionary={'name':'anil','age':22,'salary':30000}
dictionary
# Out:
# {'name': 'anil', 'age': 22, 'salary': 30000}

# %%
len(dictionary)
# Out:
# 3

# %%
dictionary['name']
# Out:
# 'anil'

# %%
dictionary['salary']
# Out:
# 30000

# %%
#replacing the value
dictionary['salary']=40000
dictionary
# Out:
# {'name': 'anil', 'age': 22, 'salary': 40000}

# %%
#add domain
dictionary['domain']='data science'
dictionary
# Out:
# {'name': 'anil', 'age': 22, 'salary': 40000, 'domain': 'data science'}

# %%
type(dictionary)
# Out:
# dict

# %%
len(dictionary)
# Out:
# 4

# %%
#deleting key value pair
del dictionary['age']
dictionary
# Out:
# {'name': 'anil', 'salary': 40000, 'domain': 'data science'}

# %%
#sorting
sorted_dict=sorted(dictionary)
sorted_dict

# %%
#keys method
dictionary.keys()
# Out:
# dict_keys(['name', 'salary', 'domain'])

# %%
#values method
dictionary.values()
# Out:
# dict_values(['anil', 40000, 'data science'])

# %%
#key value pairs
dictionary.items()
# Out:
# dict_items([('name', 'anil'), ('salary', 40000), ('domain', 'data science')])

# %%
#creating a  employee data
#key=empid
#value=name,age,salary

# %%
emp_data={
101:['abc',22,20000],102:['xyz',23,23000],103:['sdg',25,1000000]}
emp_data
# Out:
# {101: ['abc', 22, 20000], 102: ['xyz', 23, 23000], 103: ['sdg', 25, 1000000]}

# %%
emp_data[101]
# Out:
# ['abc', 22, 20000]

# %%
dict
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 del dictionary['name']
#       2 dictionary
#
# KeyError: 'name'
